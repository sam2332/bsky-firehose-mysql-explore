# %%
import mysql.connector
import time
import logging
from mysql.connector import Error

# Database configuration
MYSQL_CONFIG = {
    'host': 'mariadb',
    'database': 'bsky_db',
    'user': 'bsky_user',
    'password': 'bsky_password',
    'port': 3306
}

class MySQLDB:
    def __init__(self, config, max_retries=15):
        self.config = config
        self.max_retries = max_retries
        self.base_delay = 1  # Start with 1 second delay

    def get_connection(self):
        """Get database connection with retry logic"""
        for attempt in range(self.max_retries):
            try:
                conn = mysql.connector.connect(**self.config)
                if conn.is_connected():
                    return conn
            except Error as e:
                if attempt == self.max_retries - 1:
                    print(f"Failed to connect after {self.max_retries} attempts. Last error: {e}")
                    raise e
                
                # Exponential backoff with jitter
                delay = self.base_delay * (2 ** attempt) + (attempt * 0.1)
                print(f"Connection attempt {attempt + 1} failed: {e}. Retrying in {delay:.1f} seconds...")
                time.sleep(delay)
        
        raise Exception(f"Could not establish connection after {self.max_retries} attempts")

    def fetch_all(self, query, params=()):
        """Execute query with connection retry logic"""
        for attempt in range(self.max_retries):
            conn = None
            try:
                conn = self.get_connection()
                cur = conn.cursor(dictionary=True)
                cur.execute(query, params)
                result = cur.fetchall()
                cur.close()
                conn.close()
                return result
                
            except Error as e:
                if conn and conn.is_connected():
                    conn.close()
                
                if attempt == self.max_retries - 1:
                    print(f"Query failed after {self.max_retries} attempts. Last error: {e}")
                    raise e
                
                # Exponential backoff
                delay = self.base_delay * (2 ** attempt) + (attempt * 0.1)
                print(f"Query attempt {attempt + 1} failed: {e}. Retrying in {delay:.1f} seconds...")
                time.sleep(delay)
            
            except Exception as e:
                if conn and conn.is_connected():
                    conn.close()
                print(f"Unexpected error: {e}")
                raise e
        
        raise Exception(f"Query could not be executed after {self.max_retries} attempts")

    def get_posts_by_author_did(self, author_did):
        query = "SELECT * FROM posts WHERE author_did = %s"
        return self.fetch_all(query, (author_did,))

    def get_posts_by_user(self, user_handle):
        query = "SELECT * FROM posts WHERE author_handle = %s"
        return self.fetch_all(query, (user_handle,))

    def search_posts_by_text(self, search_term):
        query = "SELECT * FROM posts WHERE text LIKE %s"
        wildcard = f"%{search_term}%"
        return self.fetch_all(query, (wildcard,))
        
    def get_posts_by_author_handle(self, author_handle):
        query = "SELECT * FROM posts WHERE author_handle = %s"
        return self.fetch_all(query, (author_handle,))
        
    def close(self):
        # Connection is closed automatically in fetch_all
        pass

# %%
data = MySQLDB(MYSQL_CONFIG, max_retries=15)
print("Database connection initialized with retry logic (15 attempts max)")
# Out:
# Database connection initialized with retry logic (15 attempts max)

# %%
# Test database connection and get some basic stats
stats_query = """
SELECT 
    COUNT(*) as total_posts,
    COUNT(DISTINCT author_did) as unique_authors,
    COUNT(CASE WHEN author_handle IS NOT NULL THEN 1 END) as resolved_handles,
    MIN(created_at) as oldest_post,
    MAX(created_at) as newest_post
FROM posts
"""

stats = data.fetch_all(stats_query)
print("Database Statistics:")
for stat in stats:
    print(f"  Total Posts: {stat['total_posts']}")
    print(f"  Unique Authors: {stat['unique_authors']}")
    print(f"  Resolved Handles: {stat['resolved_handles']}")
    print(f"  Resolution Rate: {(stat['resolved_handles']/stat['total_posts']*100):.1f}%" if stat['total_posts'] > 0 else "N/A")
    print(f"  Oldest Post: {stat['oldest_post']}")
    print(f"  Newest Post: {stat['newest_post']}")
# Out:
# Database Statistics:
#   Total Posts: 81704
#   Unique Authors: 40660
#   Resolved Handles: 81691
#   Resolution Rate: 100.0%
#   Oldest Post: 2019-05-22 04:33:02
#   Newest Post: 2025-07-08 15:55:59

# %%
# words of sadness
words_of_sadness = [
    "sad", "unhappy", "depressed", "downcast", "sorrow", "died", "death", "cry", "tears",
    "grief", "mourning", "heartbroken", "loss", "tragic", "sorrowful", "despair",
    "melancholy", "gloomy", "dismal", "woeful", "forlorn", "desolate",
    "distress", "anguish", "pain", "suffering", "misery", "heartache",
    "lament", "weep", "sigh", "wail", "sob", "lamentation", "bereavement"
]
def find_sad_posts():
    sad_posts = []
    for word in words_of_sadness:
        posts = data.search_posts_by_text(word)
        sad_posts.extend(posts)
    return sad_posts

sad_posts = find_sad_posts()
for post in sad_posts:
    print(f"User: {post['author_handle']}, Content: {post['text']}, Date: {post['created_at']}")
# Out:
# User: wukbelav.bsky.social, Content: Y'know, one of these days i would like the ability to play fighting games again without wanting to put a bullet in my skull but sadly today is not that day, Date: 2025-07-08 01:13:27
# User: teawhilewriting.bsky.social, Content: I got on an indie game dev list for posting on indiegames but sadly I know not the first thing about coding (although I sure wish I could get in on video game scriptwriting). Am solely a player and fan 😀, Date: 2025-07-08 01:13:37
# User: basilsunflower.is.eepy.now, Content: *vuelvo del salón y la luz de mi cuarto no se enciende*
#
# yo: qué le ha pasado a la puta bombilla?
#
# literalmente la puta bombilla:, Date: 2025-07-08 01:13:16
# User: cathy12341234.bsky.social, Content: Omg i can't sleep 😴 I am thinking about a lot so really sad but I be ok I am going to listen to some folk music soon, Date: 2025-07-08 01:13:42
# User: sugarcubedog.bsky.social, Content: Feels more like trump’s personal army of sadists., Date: 2025-07-08 01:13:46
# User: greenmtnmack.bsky.social, Content: Small detail, but horses are easy targets. Just saying. A guy in full kevlar on a horse is just heavy and cumbersome enough to be totally negated should that horse suddenly cease to function.
# See also: The Crusades. Any Crusades. Pick one., Date: 2025-07-08 01:13:49
# User: diamonddustt.bsky.social, Content: Really sad I was too late for Mother's day, not only that, but I also missed Father's day!
#
# Well, Dustin has been busy lately, making a cute doggy into a mom and becoming a dad himself in the process!
#
# #Feral #FeralArt, Date: 2025-07-08 01:13:40
# User: kellywilliams.bsky.social, Content: Casadas 😌
#
# *Adorei teu icon 😍, Date: 2025-07-08 01:13:56
# User: calderondre.bsky.social, Content: nossa sim, esse é horrendo
#
# inclusive o outro já foi realmente usado por uma noiva da alta sociedade 🗣️
# #valetudo, Date: 2025-07-08 01:14:00
# User: jadesidhe.bsky.social, Content: Sad part is they're okay with that., Date: 2025-07-08 01:14:08
# User: doclaingdotcom.bsky.social, Content: It will undoubtedly be overturned on appeal or by scrotus. Sad but true., Date: 2025-07-08 01:14:09
# User: harpermeows.bsky.social, Content: im going to be legitimately really sad when sadx is used for the upcoming remaster, Date: 2025-07-08 01:14:18
# User: spectaculardl.bsky.social, Content: And sadly Cathy I don’t think she cares 🤦‍♀️, Date: 2025-07-08 01:14:21
# User: redwaterripples.bsky.social, Content: -fandom seems to, which I think makes his character very interesting because I like his flaws, so I just don't agree with most people about who he is as a person.
#
# For our deuteragonist, it's mostly when fans of his have bad takes about my faves, which is sadly often 😭. Other than that his canon-, Date: 2025-07-08 01:14:30
# User: itsrafaelaa.bsky.social, Content: Ainda bem que eu não fui lá, só pelo o que tão dizendo eu já tô arrasada, Date: 2025-07-08 01:14:32
# User: mwlacher.bsky.social, Content: Evening walk with Sadie and Jasper, Date: 2025-07-08 01:14:46
# User: lisacrispin.bsky.social, Content: It’s so sad. And, I’m a Sinner fan as well as a Grigor fan now., Date: 2025-07-08 01:14:52
# User: elpisbloom-707.bsky.social, Content: 『This meme is so old, but let's hope it aged well LOL』
#
# #FFXIV #ffxiv #sadcatdance #ffxivmeme #wolgraha, Date: 2025-07-08 01:14:52
# User: keepitbluedems.bsky.social, Content: The USA is in a really sad place., Date: 2025-07-08 01:14:54
# User: truthseeker19.bsky.social, Content: Good God.
#
# Look at all the tacky faux gold gilt behind Trump.
#
# Trump and his creepy sons Don and Eric at the White Palace is starting to look an awful lot like Saddam Hussein's Palace with his creepy sons Uday and Qusay.
#
# Tacky. Tacky. Tacky.
#
# www.independent.co.uk/news/world/a..., Date: 2025-07-08 01:15:02
# User: maybemygirl.bsky.social, Content: Muito bem casadas, amiga!😌
#
# *Obrigada, achei adorável🥹, Date: 2025-07-08 01:15:10
# User: mediceninari.bsky.social, Content: Cuando se la den en la pera va a ser demasiado tarde. “Yo no lo voté al loco!!!” van a vociferar. Por eso a no olvidarnos de los que nos hundieron con este retrasado mental perverso., Date: 2025-07-08 01:15:13
# User: goose.art, Content: every random old fuck trying to get the random other old fucks to band together against mamdani as if he is some kind of supervillain fails to realize it just makes them all look sad, Date: 2025-07-08 01:15:20
# User: sangueblaugrana.bsky.social, Content: A Gabriela não me assume e eu tenho que passar por isso. Cansada já 🙄, Date: 2025-07-08 01:15:20
# User: skyefrost.bsky.social, Content: 😭😭😭 so sad, Date: 2025-07-08 01:15:47
# User: philmarfisi.bsky.social, Content: Just returned from there too! I am an unabashed ambassador for maritime Quebec now., Date: 2025-07-08 01:15:48
# User: situador.bsky.social, Content: Situación mental: desinteresada., Date: 2025-07-08 01:15:58
# User: ehatt493.bsky.social, Content: “Ah, there’s old man Sadak.”, Date: 2025-07-08 01:16:10
# User: kgarriguesart.bsky.social, Content: They had a videochat with Lynch that you could attend, but sadly I couldn't go because I was very very broke back then, which now is a very serious "Man, I wish things were different". But still having been able to see his work up close was just something I'll never forget for as long as I live., Date: 2025-07-08 01:15:43
# User: summertimeinparis.bsky.social, Content: Nossa vcs ficaram bravos com isso mesmo PASSADA, Date: 2025-07-08 01:16:26
# User: mapleqb.bsky.social, Content: It has a slow start, it's indicative of the narrative focus of 2D zelda games that's come to a head with Echoes of Wisdom. But the dungeon designs and freedom of choice are really cool! The item rental mechanic robs the game of the sense of discovery tho as you dont find new items in dungeons, sadly, Date: 2025-07-08 01:16:33
# User: sabertoothedpie.bsky.social, Content: Lot of sad nights watching these videos tbh, Date: 2025-07-08 01:16:37
# User: talera79.bsky.social, Content: I am looking forward to this one. Sadly don't live close enough to obtain the physical packs but will be buying digital pattern access!, Date: 2025-07-08 01:16:37
# User: midimyers.com, Content: if it ends up sucking i will be very sad but the original show run is pretty impressive for a lot of reasons, Date: 2025-07-08 01:16:42
# User: gedentedlegales.bsky.social, Content: Esos son 600 años de historia, sociología, filosofía, geopolítica y deporte condensados en un reel de menos de un minuto, Date: 2025-07-08 01:16:42
# User: hlk851.bsky.social, Content: And now I want to box him. What a sad excuse for a man., Date: 2025-07-08 01:16:44
# User: navyvet80.bsky.social, Content: Trump is their Supreme MAGA Leader and that means each cult follower must compete with each other to lower the bar in being more sadistic is a huge part of this insane mob of stochastic terrorists. Following the dumbest criminal president is definitely an incredibly weird thing to do, MAGA-DUMB. 💙🇺🇸💙, Date: 2025-07-08 01:16:44
# User: benniepup1.bsky.social, Content: Hee Hee!😄 Youse so's right, Sadie! Another reason to smile!😁💓, Date: 2025-07-08 01:16:54
# User: sarcasticbarbie.bsky.social, Content: The smell of freshly cut grass is a biological engineered way plants communicate distress to one another. So everyone that loves the smell of freshly cut grass is a sick sadist. That’s the smell of freshly cut bodies crying out a warning to their brethren & you have it as a scentzie in your kitchen, Date: 2025-07-08 01:17:05
# User: bitseok.bsky.social, Content: #bitcall atrasada demais porque sou workaholic, mas quero muito amizades pro jungseok, então antes tarde que nunca!! deixa um likezinho se quiser uma dm ic misteriosa 🙏🏻, Date: 2025-07-08 01:17:04
# User: knurella.bsky.social, Content: Zasadziła na swojej łące nomadowa, Date: 2025-07-08 01:17:14
# User: tokyotrendnews.bsky.social, Content: Former U.S. ambassador to Israel examines Trump-Netanyahu meeting #CBSNews
#
# Former U.S. ambassador to Israel examines Trump-Netanyahu meeting Israeli Prime Minister Benjamin Netanyahu is visiting the White House for talks with President Trump on Iran and the war in Gaza. Daniel Shapiro, U.S.…, Date: 2025-07-08 01:17:13
# User: marromcafe.bsky.social, Content: Não, Raquel
# Cê chega dando tapa na cara e não contando historinha emocional do passado
# Não acaba com o clima de vingança prometida
# #ValeTudo, Date: 2025-07-08 01:17:15
# User: yukhey.bsky.social, Content: RAQUEL CHAMOU ODETE ROITMAN DE PROSTITUTA???? PASSADA #valetudo, Date: 2025-07-08 01:17:16
# User: frodo58.bsky.social, Content: East Palestine Ohio anybody? Everyone knows Blazing Saddles, and when they were Deputizing everyone. So, with that being said you know the Accent that is used with this line! I change 1 word but it fits. "We Don't Need No STINKING FEMA"! Get it? Migrants don't qualify! ICE can rehouse them in Fla.💜🖖, Date: 2025-07-08 01:17:20
# User: glenallen2010.bsky.social, Content: People like DeSantis, with nothing to offer, find themselves kissing asses their entire life. Sad., Date: 2025-07-08 01:17:24
# User: writingbybethany.bsky.social, Content: #UnhingedPit Ambassador here...make sure you review the #UnhingedPit Rules and follow @unhingedpit.bsky.social! #WritingCommunity, Date: 2025-07-08 01:17:24
# User: iarices.bsky.social, Content: ela falando essas coisas como se odete e a celina tbm não tivessem casado por interesse......., Date: 2025-07-08 01:17:31
# User: jenglambie.bsky.social, Content: Those phone text messages between police officers were revealing, confronting & sadly, not in the least surprising in their racist content., Date: 2025-07-08 01:17:33
# User: felixdoessomestuff.bsky.social, Content: didnt get around to painting my nails today either cuz i was too sad, dont think tomorrow is gonna be much better either. cant seem to shake this depression off no matter what i do/dont do., Date: 2025-07-08 01:17:37
# User: rodrigobsss.bsky.social, Content: Que vergonhosa essa gentalha.
#
# Semana passada desmereceram o evento dos BRICS adoidado, até com a fake 2.0 da Sadi sobre a Janja e o Xi.
# Agora o Zacarias da economia elogia o evento, mas o timing foi derrubado pelo Trump saber controlar o enredo.
#
# Mas eles próprios estão alimentando o tema 🤡🤷‍♂️, Date: 2025-07-08 01:17:43
# User: vhsverde.bsky.social, Content: tia celina está PASSADA, Date: 2025-07-08 01:17:44
# User: brunurbano.bsky.social, Content: a Odete CÍNICA ta FINGINDO que tá SUPER interessada no que Raquel tá querendo falar #ValeTudo, Date: 2025-07-08 01:17:47
# User: nabil1.gaza.click, Content: In Gaza, we measure time by how long we can hold on. Please, let your kindness stretch our tomorrows. @sadcomrade.bsky.social, Date: 2025-07-08 01:17:48
# User: tobesobaghin.bsky.social, Content: CALHORDA é uma palavra pesada
#
# #ValeTudo, Date: 2025-07-08 01:17:55
# User: litweeta.bsky.social, Content: eu queria acordar e tudo ted sido um pesadelo, Date: 2025-07-08 01:18:03
# User: mistersniffer.bsky.social, Content: yeah, he's the sad stalker.
# this is his life now, lol.
#
# if he can't even handle a little mockery from the louvre, i dunno how he thinks he's gonna take on actual, real, fascism., Date: 2025-07-08 01:18:04
# User: fauxly.bsky.social, Content: with the only disadvantage being that its so mentally demanding i can't play it for long sittings, Date: 2025-07-08 01:18:08
# User: maitreyaouroboros.bsky.social, Content: It's both adorable and sad. They know that humans are the gatekeepers to additional resources., Date: 2025-07-08 01:18:09
# User: hocuspocusblade.bsky.social, Content: The sad part about it is that he thinks he's 'so hot'., Date: 2025-07-08 01:18:09
# User: davidhalchester.bsky.social, Content: the feeling I get when I ask someone to do a job is 1) what's in it for me? 2) mmm, no I don't have time 3) who are you again? 4) I don't want to be seen in a video, so you can't film me singing 5) I don't want to use my real name... and other fun things like this.
#
# It makes me sad, but I guess, Date: 2025-07-08 01:18:11
# User: sykoscorch.bsky.social, Content: Yeah they're the kind of thing I just don't eat because it makes me sad, lol. I'd rather find new things to eat than have diet-diet food the rest of my life.
#
# The Gluten Free Oreos are a goddamn godsend, Date: 2025-07-08 01:18:13
# User: gjkhgvvvyy.bsky.social, Content: @sadomasochist.bsky.social 🙏🏻
# I beg you
# I beg you
# I kiss your head.
# Only 7 days left.
# Help me save my son Ahmed's life.
# I'm so tired.
# Help me by donating or sharing.
# Ahmed's campaign is pinned on my page 💔😭, Date: 2025-07-08 01:18:16
# User: redninjared.bsky.social, Content: so sad. but.. you're borderline gen alpha... that may be worse 😭😭😭, Date: 2025-07-08 01:18:20
# User: acidelicious.bsky.social, Content: Risadas sinceras no meio do drama #ValeTudo, Date: 2025-07-08 01:18:21
# User: jkcreative8.bsky.social, Content: How sad., Date: 2025-07-08 01:18:35
# User: liliancris.bsky.social, Content: cansada desse recap da raquel. #ValeTudo, Date: 2025-07-08 01:18:35
# User: dagodaddy45.bsky.social, Content: Gang bang birthday madness
# @nastybynature64.bsky.social
# @backindasaddle.bsky.social
# @badsantabp.bsky.social
#
# Please like and repost
#
# See more at justfor.fans/DagoDaddy45?..., Date: 2025-07-08 01:18:34
# User: whardy.bsky.social, Content: Don’t worry Donnie. Mosad has evidence of everything. Pictures, videos, documents, everything., Date: 2025-07-08 01:18:35
# User: chicoproductions.bsky.social, Content: Paul got us with the fake sad face! Lol #wwe #wweraw, Date: 2025-07-08 01:18:38
# User: 2g4y.bsky.social, Content: Sadly!🙄😒😓/
# Imagine having your fave anime bae on your 120 gig floppy.   Ill buy a shino themed floppy 💾, Date: 2025-07-08 01:18:52
# User: sundevil-1984.bsky.social, Content: And Mexico is helping with the search and rescue. America is a sad joke., Date: 2025-07-08 01:18:54
# User: patrickmin.bsky.social, Content: Followed up with Diplomat G90!
# South Korean Ambassador?
# #weirdcarBS, Date: 2025-07-08 01:18:52
# User: lili-68.bsky.social, Content: I was on a job today and I heard a bullfrog, he was barking like a dog. While I was tryna find him, I remembered a t-shirt I had as a kid; it was a restaurant and th sign said, Today's Special: Frog Legs... and all th sad little frogs were in wheelchairs leaving th kitchen..., Date: 2025-07-08 01:18:56
# User: 0andreluiz.bsky.social, Content: a risadinha da Fátima me pegou demais hahahahaha #ValeTudo, Date: 2025-07-08 01:19:08
# User: felixdoessomestuff.bsky.social, Content: didn't get around to painting my nails today either cuz i was too sad, don't think tomorrow is gonna be much better. cant seem to shake this depression no matter what i do/don't do., Date: 2025-07-08 01:19:08
# User: sandverge.bsky.social, Content: Sadly, trying to appeal to principles they don't have. I wish a few more voters saw Christianity the way he does., Date: 2025-07-08 01:19:14
# User: blabalino.com, Content: We deserve better than that. Here's what we get in Norway. Bernie chats with the Norwegian Ambassador about it:
# youtu.be/g0XS6ke1B1I, Date: 2025-07-08 01:19:16
# User: en.scares.men, Content: feeling like crap today but it's a long ass day so i dont have the time to be sad or useless, Date: 2025-07-08 01:19:26
# User: blackazizanansi.bsky.social, Content: Whenever someone posts about Rufo, I automatically read Rufio and get happy, but once i realize the post is not in fact about Rufio, then i get sad., Date: 2025-07-08 01:19:46
# User: dfortytwo.bsky.social, Content: This is absolutely wild.  Really sad, too., Date: 2025-07-08 01:20:01
# User: vampyeve.bsky.social, Content: agora eu vejo que algumas que eu só usei como objeto na verdade me amaram
#
# me amarraram no passado pq agora eu entendo como eu fui um otário, Date: 2025-07-08 01:20:07
# User: dannyjnoonan.bsky.social, Content: This is so sad., Date: 2025-07-08 01:20:11
# User: hotcheetoyo.bsky.social, Content: I’ll never forget my parents took me & my cousin to a monster truck rally when I was like 4-5 & had to leave early bc he cried. I was so sad, Date: 2025-07-08 01:20:13
# User: pinodionigi.bsky.social, Content: Sadly I see it from outside of your country that you have become a sellout! Not a word from you in support of Palestinians. Not a word in support of Mamdani., Date: 2025-07-08 01:20:13
# User: kdramom.bsky.social, Content: I’m really sad I’m already caught up on #marrymyhusband Japan. Should I…rewatch the Korean version while I wait? Probably too confusion to watch them at the same time. #kdrama #jdrama, Date: 2025-07-08 01:20:14
# User: nebulose-cloud.bsky.social, Content: The plot of every Vikjayce fic ever:
#
# - one of them breaks into the other's lab
# - Jayce is sad Viktor is becoming a machine. Vik is sad Jayce exiled him.
# - the fight (erotically)
# - Jayce calls Vik Vitya (seductively)
# - Viktor lets him take off his mask
# - They kiss passionately, forgetting their, Date: 2025-07-08 01:20:21
# User: lexigreywinds.bsky.social, Content: Anthrocon 25 is over, I am sad. I had a lot of fun though!, Date: 2025-07-08 01:20:17
# User: zyblonius.bsky.social, Content: Good ol' sad cello serial killer procedurals., Date: 2025-07-08 01:20:25
# User: pobritaygordita.bsky.social, Content: O bom das lives no TikTok é que as vezes to na maior tristeza, chorando com as músicas e do nada aparece um ganso na cabeça dele ou um gato no canto da tela e eu dou uma risadinha, Date: 2025-07-08 01:20:25
# User: morimole.bsky.social, Content: They hated Mr. Rogers back in the day. Sadly, it's not a new phenomenon., Date: 2025-07-08 01:20:29
# User: badwitchmaris.bsky.social, Content: Chocada em saber que a Tia Celina já foi casada kkkk pra mim ela era uma eterna solteirona #ValeTudo, Date: 2025-07-08 01:20:31
# User: cospopolsku.bsky.social, Content: El inicio sobretodo es fumada rara, de hecho el primer cap me disgustó cierta parte que pensé "ok, japonesada, creo que dejaré de verlo", Date: 2025-07-08 01:20:30
# User: us-news.bsky.social, Content: Every living NASA science chief unites in…
#
# https://www.europesays.com/us/47396/
#
# Pasadena, CA (July 7, 2025) — In a joint statement, every living former head of NASA’s Science Mission…#us #news #usnews, Date: 2025-07-08 01:20:30
# User: miniminimisterio.bsky.social, Content: passada com essa cena (amei), Date: 2025-07-08 01:20:44
# User: sujato.bsky.social, Content: (Back home now, with new fillings!)
#
# Maxwell did away with all that, reducing academia to a numbers game of citations and rankings.
#
# He also, incidentally,
#
# - trafficked the surveillance software (PROMIS) now evolved to Palantir;
# - helped establish Israel and served as Mossad agent;, Date: 2025-07-08 01:20:31
# User: dangusmao.bsky.social, Content: ainda muito passado com o plano de saúde da brisanet KKKK, Date: 2025-07-08 01:20:51
# User: pequenadu.bsky.social, Content: E Celina passada chocada, Date: 2025-07-08 01:20:56
# User: dcapto.bsky.social, Content: I was being facetious about the last part but I really thought you meant a third of people were masked. Being one of only 3 people masked makes more sense, sadly, Date: 2025-07-08 01:20:58
# User: nadojacksie.bsky.social, Content: Squirrel !
#
# He is a vile sadistic criminal., Date: 2025-07-08 01:21:03
# User: missmwambe.bsky.social, Content: « C'est notre posadka, bande d'enfoirés. »
# Une phrase criée au combat par les soldats de la 3e brigade d'assaut...elle a immédiatement trouvé un écho auprès de millions de personnes.
# Elle est devenue un symbole. On la retrouve sur les patchs, sur les murs...
#
# x.com/414magyarbir..., Date: 2025-07-08 01:21:05
# User: navyvet80.bsky.social, Content: Trump is a cruel inhumane sadistic xenophobic goose-stepping Nazi and his Minions are dedicated to dividing our nation permanently as seen from the rallies protesting against the senile geriatric president's Fascist agenda. Empathy is considered a weakness by these soulless racist crazy people.
# 💙🇺🇸💙, Date: 2025-07-08 01:21:10
# User: seasherm.bsky.social, Content: Sad little man. A reminder that Palestinians are Semites. Note that Jews moved to Palestine before they stole it back and called it Israel. Just like in the Old Testament., Date: 2025-07-08 01:21:15
# User: thespeciousreport.bsky.social, Content: Sadly, the rest of us Texans get the leadership the razor-thin idiot trash majority keeps voting for. Maybe someday..., Date: 2025-07-08 01:21:14
# User: sammytighe.bsky.social, Content: Already did a couple MVC drawings sadly, Date: 2025-07-08 01:21:27
# User: aylladias.bsky.social, Content: Só exposed pesado lá na rede vizinha sobre a mãe da Marília Mendonça, triste com o que estão fazendo com a memória dela., Date: 2025-07-08 01:21:31
# User: elizabethrivian.bsky.social, Content: This is just sad., Date: 2025-07-08 01:21:32
# User: pablopz.bsky.social, Content: Cómo los traumas del pasado condicionan tu presente, Date: 2025-07-08 01:21:34
# User: beckyingr.bsky.social, Content: FOX Business recently ran a story about some firm that analyzed the chatter supporting the drops and it was mostly bots. The stock prices and store traffic tell another story. I’m befuddled at the huge disconnect between reality and the Rufo/Kirk/Heritage chokehold on these papers and CEOs. Sad., Date: 2025-07-08 01:21:47
# User: kyledykstra.bsky.social, Content: Added some hard bags to the Vulcan Custom...love them!  Now I have some storage with me when I need it and can quickly remove the saddlebags when I don't need the storage!
#
# Viking Lamellar Stallion XL and Viking Quick Disconnect kit
#
# #VikingBags
# #Kawasaki
# #Vulcan, Date: 2025-07-08 01:21:45
# User: aaronmarx.bsky.social, Content: OMG:  And in the NYT’s favorite “Headline as a question” format!!!
#
# The next one can be “Questions Linger Over NYT’s Crusade”, and then “Concerns Continue To Mount”, Date: 2025-07-08 01:21:51
# User: raantuva.fyi, Content: I should be shocked by this, I'm just not, sadly., Date: 2025-07-08 01:22:03
# User: joesegal.bsky.social, Content: they only stopped segregation when the nation saw firehoses and dogs set on black children on TV.  We only went to war when Japan bombed Perl Harbor. It takes a lot to rouse America to action. Trump's getting close to that. lots of folks still aren't paying attention. Sadly., Date: 2025-07-08 01:22:14
# User: elenaerrante.bsky.social, Content: parabéns, amiga (alguns meses atrasado kkkkkk) ❤️, Date: 2025-07-08 01:22:07
# User: cuckoldsp.bsky.social, Content: Putao casado tava de pica dura no banheiro do terminal de ônibus, eu cai de boca e mamei gostoso a piroca grossa dele
#
# 🌟 vem assistir completo, vídeo disponível nas plataformas digitais.
# onnowplay.com/diariodaputaria/1565, Date: 2025-07-08 01:22:06
# User: ellipticalnight.bsky.social, Content: Caroline Dawson was a writer here whose first novel should have been the beginning of a long career, but very sadly was the only one she had a chance to publish, and naming a new library after a young writer gone far too soon is such a moving gesture, Date: 2025-07-08 01:22:10
# User: okiraku-ch.bsky.social, Content: That's right! Let's go to work ٩( ๑•̀o•́๑ )و
# The express train I was originally going to take was cancelled. I was told to take the Tennoji Express... I lost my seat (sad)
# Today's #iron, Date: 2025-07-08 01:22:07
# User: vishalicious213.bsky.social, Content: Took los kiddos & @sirashtondev.bsky.social to Odyssey Games in Pasadena so we can be big nerds., Date: 2025-07-08 01:22:13
# User: gm112.bsky.social, Content: I wonder when people will stop working with Materia Collective. They've been toxic for years. Kind of sad Toby Fox decided to work with them for Deltarune again, thought they wouldve learned not to after how Materia Collective tried to claim that they own Toby's music., Date: 2025-07-08 01:22:34
# User: kryptopupp.bsky.social, Content: Sure did, Sadly you can’t really push them once they start to turn into mashed potatoes texture lol wish they were better I really like how they feel vintage tumblr abdl discovery vibes, Date: 2025-07-08 01:22:38
# User: yummymoyashi.bsky.social, Content: Yeah, I don’t need a pc port but it’s sad for people who do 😔
# but regardless I’m happy it’s still comming to the west! I wanted this game so badly during its first kickstarter, Date: 2025-07-08 01:22:56
# User: rystorm.bsky.social, Content: Sadly no, Date: 2025-07-08 01:22:58
# User: chroniccuteness.bsky.social, Content: I don't mean it in a bad / sad / depressive way, I just reeeeeeeaaaaally want to do what's right. :''3c, Date: 2025-07-08 01:22:55
# User: luckyf77.bsky.social, Content: So fucking sad 💔, Date: 2025-07-08 01:23:03
# User: paulalaurentino.bsky.social, Content: dei uma passada de olho rápida pelo esgoto da outra rede depois de muito muito tempo só pra ver como tava, e em menos de um minuto vi 75 desgraças diferentes
#
# honestamente, tenho certeza que parte da melhora da minha ansiedade é por ter diminuído meu grau de exposição à chuva de informações pesadas, Date: 2025-07-08 01:23:05
# User: tom2050.bsky.social, Content: As a sadist and sociopath, he clearly likes it, Date: 2025-07-08 01:23:10
# User: zeoffline.bsky.social, Content: como assim já fez 13 anos que o the radio dept fez show aqui? passado., Date: 2025-07-08 01:23:14
# User: tinsay.bsky.social, Content: sadly i have no references for that,,, Date: 2025-07-08 01:23:15
# User: darkredfox.bsky.social, Content: I'm too sore rn to be sad and depressed lol, Date: 2025-07-08 01:23:15
# User: hugosd.bsky.social, Content: essa cena perde muito o peso sem o ivan casado, Date: 2025-07-08 01:23:15
# User: ds500.bsky.social, Content: This speaks to me, sadly!, Date: 2025-07-08 01:23:21
# User: ofertas.bsky.social, Content: Samsung Smart TV 50" UHD 4K 50DU7700 - Processador Crystal 4K, Gaming Hub -- Amazon
#
# R$ 2.149,00
# Compre aqui ⬇️⬇️, Date: 2025-07-08 01:23:21
# User: promocoesbr.bsky.social, Content: Samsung Smart TV 50" UHD 4K 50DU7700 - Processador Crystal 4K, Gaming Hub
#
# 💵 R$ 2.149,00
#
# Promoção Amazon 👇👇, Date: 2025-07-08 01:23:24
# User: gaystation64.bsky.social, Content: It's a dead horse, but this reminds me how sad the fall of The Young Turks has been. Shredding their goodwill to chase an oversaturated market of grifters., Date: 2025-07-08 01:23:36
# User: diannewa.bsky.social, Content: I had the first three letters in two tries. I finally solved it in six. Sometimes having an extensive vocabulary is a disadvantage!, Date: 2025-07-08 01:23:42
# User: onbehalfofhefool.bsky.social, Content: Sadly true. TACO has said as much., Date: 2025-07-08 01:23:48
# User: ashgunnywolf.bsky.social, Content: He looks like a Pound Puppy ;-; Saddest wettest little baby at the shelter, Date: 2025-07-08 01:23:52
# User: fenrislupus.bsky.social, Content: Eu queria saber se a Asato Asato (autora de 86) tá bem. Porra, a mulher tava passando uns tempos adoentada, melhorou, daí ficou meio doente depois de novo. Saiu o volume 13 no começo do ano passado e depois não sei se teve notícias., Date: 2025-07-08 01:24:12
# User: espinsegall.bsky.social, Content: They are coming for same-sex marriage.
# Get ready.
# I’m unconscionably sad to report it’s likely to be a state issue in 5 years.
# Unlike abortion, the text of the 14th Amendment should preserve it.
# Equal Protection Under the Law.
# But I’m worried., Date: 2025-07-08 01:24:16
# User: certifiedblazed.bsky.social, Content: Sad to see him go. Glad to see him go to a contender., Date: 2025-07-08 01:24:25
# User: acervoonnowplay.bsky.social, Content: Putao casado tava de pica dura no banheiro do terminal de ônibus, eu cai de boca e mamei gostoso a piroca grossa dele
#
# 🌟 vem assistir completo, vídeo disponível nas plataformas digitais.
# onnowplay.com/diariodaputaria/1565, Date: 2025-07-08 01:24:25
# User: lmenthe.bsky.social, Content: So saddened by the Texas floods. Every day the news gets worse… Hoping that the weather breaks soon and no more are lost., Date: 2025-07-08 01:24:31
# User: otheeduardo.bsky.social, Content: "Eu perdi tudo" diz a mulher que literalmente acabou de ganhar um milhão de reais semana passada, Date: 2025-07-08 01:24:37
# User: rohmac.bsky.social, Content: So sad... donating to this week's Big Sleepout is one way to help.
#
# www.bigsleepout.org.nz, Date: 2025-07-08 01:25:25
# User: craftsunemiku.bsky.social, Content: Quests like this happening during major threat events are always kinda funny and sad at the same time... like c'mon guys come back later this is NOT a good time, Date: 2025-07-08 01:24:39
# User: volumetric.bsky.social, Content: Not a look I think I could pull off sadly., Date: 2025-07-08 01:24:44
# User: bo-locks.bsky.social, Content: 2)& active, less visible but equally significant is its influence within the Netherlands’ security apparatus, especially intelligence agencies & police forces
#
# Dutch intelligence agencies have established cooperation agreements with Israeli counterparts such as Mossad and Shin Bet
#
# While these..., Date: 2025-07-08 01:24:43
# User: donsheldon.bsky.social, Content: <screamed over high winds through a maxed out microphone> "What's that? Which body of water did he land in? Sorry, I don't know where that is. This will make the search and rescue effort very difficult. Too bad. So sad. Let's quit and go get pizza.", Date: 2025-07-08 01:24:56
# User: htsresist17.bsky.social, Content: Sad thing is some people do believe them., Date: 2025-07-08 01:25:02
# User: rircardinho.bsky.social, Content: Passado com essa cena……, Date: 2025-07-08 01:25:02
# User: vp2.bsky.social, Content: Meu deuuussss... ele cantando todas juntas assim.. as nkvas.. antigas deles.. só confirma o pesadelo que é... pqp, Date: 2025-07-08 01:25:15
# User: luchobordegaray.bsky.social, Content: Pido permiso por ser un improvisado, pero ¿no es un tordo renegrido?, Date: 2025-07-08 01:25:18
# User: pyonkotchi.com, Content: did u know passion comes from the latin word for suffering? which is why i should make alex a little sadder, Date: 2025-07-08 01:25:15
# User: gabudoesstuff.bsky.social, Content: ela ter usado algas de verdade lra fazer um vestido bioluminescencia cara toda vez ela cai la e chuta a porta eu amo ela, Date: 2025-07-08 01:25:21
# User: studyroom.bsky.social, Content: charles era sozinho na fazenda, mal mantida por ele, q sentia falta princip. do irmão. encontrava-se com prostitutas frequentemente. certo dia sofre acidente e tem marcado na testa uma cicatriz escura e chamativa. adam eh dispensado, mas n consegue voltar. se alista de novo. e encontra o pai, Date: 2025-07-08 01:25:27
# User: wiswell.bsky.social, Content: Megara turns to walk away sadly. Presumably in a minute she'll remember she flew here., Date: 2025-07-08 01:25:31
# User: sakuloko.bsky.social, Content:  Trump acusado de liderar la Casa Blanca como jefe mafioso “Presidencia del Padrino”
#
# thetimes.lat/contenido/62..., Date: 2025-07-08 01:25:26
# User: carlring.bsky.social, Content: read to the end, and then read it again:
#
# "“Unspeakable tragedy,” people used to say, meaning sadness so deep it cannot be expressed. But we must speak of tragedies as tragedies, and of cruelty as cruelty. When we don’t, it becomes “normal” — or even celebrated.", Date: 2025-07-08 01:25:45
# User: nvharemway.bsky.social, Content: just wanna let y'all know I'm ok. barely.
# as a parent,caretaker, and sole breadwinner of my family I'm simply not coping 100% of the time as expected by many, so I just don't have the energy to commit to being horny. I do feel sad when I don't post anything so I guess the fire isn't out just yet., Date: 2025-07-08 01:25:45
# User: angelaisms.bsky.social, Content: That… makes me sad., Date: 2025-07-08 01:25:48
# User: zeeek.bsky.social, Content: There should have been executions over this trial and they all just got away with it because Epstein had ties to mossad., Date: 2025-07-08 01:25:53
# User: elizabethp12.bsky.social, Content: Sadly missed. RIP, Date: 2025-07-08 01:25:58
# User: adellisauthor.bsky.social, Content: GO NOW! Buy your tickets before they are sold out and you have to be sad. #booklovers #reading #bookworms #bookevent #getyourtickets, Date: 2025-07-08 01:26:03
# User: toepicktrips.bsky.social, Content: No words, just sadness for the kids who were failed by adults who had the opportunity to do better., Date: 2025-07-08 01:26:02
# User: notpickard.com, Content: its weird feeling having a depressive episode that is just the brain chemical effects. no sadness dog lying on your chest
#
# its kind of like having a bad trip but you've done it enough that you actually know it will pass and your environment is actually pretty well set up to absorb the psychic attack, Date: 2025-07-08 01:26:14
# User: emiliolindosa.bsky.social, Content: TVE ha usado Inteligencia Artificial para falsear la historia de Juan Etxepare, republicano que lanzó el primer txupinazo en Iruñea en 1931. Dicen que "desapareció misteriosamente", obviando que fue asesinado en 1936 por los fascistas, Date: 2025-07-08 01:26:17
# User: jt-retiredmedic.bsky.social, Content: Sister, I feel like I'm in some Twighlight Zone episode playing on a loop.
# Selective racist Christian white people of all ages wanting so badly to be hipsters, cosmopolitan and sophisticated but failing so miserably.
#
# It's sad to watch., Date: 2025-07-08 01:26:18
# User: parallaxa.bsky.social, Content: Elektrovojvodina is one of the standout examples of brutalist architecture in #NoviSad ⚡️
#
# More brutalist gems from the city in my latest blog post → shorturl.at/pa0Dz
#
# #brutalism #brutalist #architecturephotography #streetphotography #urbanphotography #serbia #soviet #socialism #photographer, Date: 2025-07-08 01:25:46
# User: cardjunk.bsky.social, Content: Catchpenny Comics #1
# a really good anthology comic in a variety of styles, from surreal to sci-fi to murder
# really good stuff but sadly the Ramona the Robot story is continued in issue #2 and as far as i can tell there is no issue #2
# even worse there's a sneak preview of the stories in there!, Date: 2025-07-08 01:26:03
# User: rrdporter.bsky.social, Content: Ugh!  Sadly, we’re too late. We have now been turned into a racist country. We still need to keep up the fight, no matter how bad it looks. We can eventually recover, but I’m afraid not in my lifetime 😢, Date: 2025-07-08 01:26:31
# User: deermints.bsky.social, Content: i have been tempted to inflict them upon @tyrantrat.bsky.social so this is sad news, Date: 2025-07-08 01:26:31
# User: dergrexxie.bsky.social, Content: I'm eating a quesadilla with one hand and scrolling with the other right now. Corporate media has no honor now, only shame., Date: 2025-07-08 01:26:37
# User: izzykamikaze.bsky.social, Content: Sadly, I can't see it making much difference to his behaviour., Date: 2025-07-08 01:26:40
# User: fallout71.bsky.social, Content: lol that’s even sadder than if you were, Date: 2025-07-08 01:26:41
# User: xc90v8.bsky.social, Content: They won't turn even when they're directly harmed. A feature of sado-populism....., Date: 2025-07-08 01:26:46
# User: matt872.bsky.social, Content: Freedom of speech.  Deal with it. And you don’t even iniquity why Rep. Jeffries read several verses during his filibuster is very sad on your part.
# I’m an Atheist and I even know why., Date: 2025-07-08 01:26:56
# User: jayrosen.bsky.social, Content: "With this made-up scandal, combined with the pre-election editorial, the Times looks like it’s on a crusade against Mamdani."
#
# That's Margaret Sullivan @sulliview.bsky.social Former public editor of the New York Times, and a shrewd judge of newsroom character. www.theguardian.com/commentisfre..., Date: 2025-07-08 01:26:57
# User: scottletteau.bsky.social, Content: T's fun. Unbridled fun. He's crazy. Cute. Exudes the spirit of adventure. Part Kodai Susumu, part a river otter video, part soviet astronaut. All fun. Some sadness and longing for home., Date: 2025-07-08 01:27:02
# User: denisemct.bsky.social, Content: No. It's outrageous. And cruel. And now, sadly, America., Date: 2025-07-08 01:27:20
# User: silentstares.bsky.social, Content: This is so sad and sweet and beautiful i love the composition and the  entire concept and the QUALITY wow!!! Aaaaa, Date: 2025-07-08 01:27:20
# User: theredjoka.bsky.social, Content: Sad part is about mine.....my is my actual name my middle name to be exact, Date: 2025-07-08 01:27:21
# User: browneyegirlhi.bsky.social, Content: I'm so sad.  Please, please, be very careful, y'all.  Sending my deepest condolences to the family. 😭💔🙏🏼, Date: 2025-07-08 01:27:23
# User: olddumbguy.bsky.social, Content: Any guesses how long it will take for midwesterners to recognize and admit that their vote for pres felon & his tariff games have lost them nearly 50% of their corn export contracts?  And the loss of their farms and associated businesses and towns?  FAFO sadly. Just sayin., Date: 2025-07-08 01:27:39
# User: ggl25.bsky.social, Content: Sad but not surprising, Date: 2025-07-08 01:27:42
# User: robertmcmillan.bsky.social, Content: Sadly they do thing of it as personal growth. It's just their idea of personal growth is warped. Like "Cheaper by the Dozen" on meth. To them personal growth revolves around acquiring money, possessions, and influence. Never have I heard one talk about family or deep contentment., Date: 2025-07-08 01:27:44
# User: efe.com, Content: México está interesado en «superar toda controversia» con España y «fortalecer los lazos» que son «ancestrales», expresa el presidente del Senado, Gerardo Fernández Noroña.
# , Date: 2025-07-08 01:27:53
# User: joaniejabronie.bsky.social, Content: the cycle of working on this comic:
# - wow, i am so excited about this comic
# - can’t wait to do good work on this comic
# - oh no it’s time to work on the comic
# - this is bad, i am a fraud
# - i need to put this down because now i am sad
# - actually it looks p good
# - wow, i am so excited about this comic, Date: 2025-07-08 01:28:04
# User: guillermosantos.bsky.social, Content: passada que Bella Campos está servindo, perdão por todas as vezes que duvidei (todas), Date: 2025-07-08 01:28:09
# User: us-political-news.bsky.social, Content: Scoop: Waltz finally gets Senate hearing for UN post https://www.axios.com/2025/07/08/mike-waltz-un-ambassador-trump-senate-hearing https://www.axios.com/2025/07/08/mike-waltz-un-ambassador-trump-senate-hearing, Date: 2025-07-08 01:28:12
# User: nomoredramala.bsky.social, Content: Put a bag of chocolate chips in front of me and it’s the same sad song., Date: 2025-07-08 01:28:18
# User: sassysister27.bsky.social, Content: That’s sadly true…I can only think of one place where a bomb really needs to be dropped…, Date: 2025-07-08 01:28:24
# User: seatowngirl12.bsky.social, Content: Sadly can’t really say I’m surprised. 🤦🏻‍♀️, Date: 2025-07-08 01:28:25
# User: anarchist-araqorn.bsky.social, Content: Alabama, sadly my home state, is even a failure at carrying out the death sentences it prescribes to its people. After failing to kill someone by lethal injection they turned to human experimentation with nitrogen., Date: 2025-07-08 01:28:30
# User: anirave.bsky.social, Content: Sadly, I pour all of my money into sequences every month 😅. So I have to settle for collecting fan made .stl files to print when my 3D printer gets fixed., Date: 2025-07-08 01:28:33
# User: wanwanattack.qtbrewer.moe, Content: It's a total non-issue, of course, but I really adore handsome girls and seeing people kinda start labelling them like that makes me feel weirdly antsy. If people did that with the handsome girls I wrote I'd be a little sad., Date: 2025-07-08 01:28:36
# User: assimfaloubea.bsky.social, Content: - seduza uma moça que não possui nada haver com o alvo de sua vingança
# - minta sobre toda sua identidade e esconda que é casado
# - abandone ela na beira da estrada depois da noite de núpcias
# - se arrependa e depois mantenha ela em cárcere privado, Date: 2025-07-08 01:28:36
# User: dashingclaire.bsky.social, Content: White supremacist, Nazi, fascist, felon, racist, rapist, sadistic murderer "Noble Peace Prize" loser. 🤣🤣🤣, Date: 2025-07-08 01:28:42
# User: viktoriapetrov1.bsky.social, Content: It’s been a year since I lost my dog Ramsey to a hit and run. Some days the sadness still feels just as heavy. I miss him so much and the house feels too quiet and empty.  I still find myself wishing he was here keeping me company especially on the lonely days. He was my little shadow, comfort & joy, Date: 2025-07-08 01:28:28
# User: skylorforscythe.bsky.social, Content: Even if I wasn't sad, if Tabatha offered, I'm definitely going to give those lovely breasts a squeeze. 😍, Date: 2025-07-08 01:28:58
# User: kmboaf.bsky.social, Content: solto uma risadinha gostosa sempre que lembro daquele quote de ays  Hyung you should get naked 😏 ... I'm actually neurodivergent, Date: 2025-07-08 01:28:44
# User: petenaps.bsky.social, Content: You are so naive. Nobody with a gun issued by the government is on your side. Not one. Sadly, we're all going to learn the hard way., Date: 2025-07-08 01:28:58
# User: maxldunn.bsky.social, Content: LOL these MAGA scum actually believe their bullshit conspiracy lies AND the orange con artist.
#
# It must be really sad to be so profoundly stupid and gullible.
#
# I almost feel sorry for the racist bitches, watching them infight and implode on Twitter. Then I remember their treason. Let them infight., Date: 2025-07-08 01:29:04
# User: lonelyjapan.bsky.social, Content: Perks and disadvantages moving to Japan 2 years
#
# https://www.lonelyjapan.com/252306/
#
# Hi, Me and my wife (no kids, both europeans) have the chance to move to Japan by internal…, Date: 2025-07-08 01:29:03
# User: audiovintagebr.bsky.social, Content: Leia um bom artigo: blogsadoutrinachannel.blogspot.com/2024/03/5-ci..., Date: 2025-07-08 01:29:04
# User: cws1958.bsky.social, Content: sad fact he probably going to get a lot of followers nothing like Trump, Date: 2025-07-08 01:29:11
# User: kiyoldk.bsky.social, Content: I agree. Probably not a hot take though.
#
# Just a sad reality of the Tik-tok-ification of meme culture., Date: 2025-07-08 01:29:23
# User: modernetimes1.bsky.social, Content: Wow it’s really sad to see how far America has fallen since January 20, 2025. Domestic Kidnapping, drop in GDP, economic depression, loss of ability to protect Americans, loss of healthcare, loss of respectability & diplomacy in the world. MAGA-Making America Grotesque Again., Date: 2025-07-08 01:29:24
# User: mininotubarao.bsky.social, Content: É real é muito comum entre as populacoes de spinossauro pesquisadores dizem, Date: 2025-07-08 01:29:23
# User: giuliagreppi.bsky.social, Content: eu amei o tapa, arrasou na rasgação, muito bom o choro, o grito da mão cheia de cebola, o grito de DISGRASADA, Date: 2025-07-08 01:29:33
# User: houdinix.bsky.social, Content: ela jura tanto que tá tudo bem que semana passada me perguntou se eu queria ter “alta”, risos, Date: 2025-07-08 01:29:39
# User: imhisru.bsky.social, Content: The saddest thought today, for me, is knowing that the Republican Party will exist after the mid-terms with absolutely no viable way to destroy it., Date: 2025-07-08 01:29:44
# User: lbbl.bsky.social, Content: The second I saw the year,  I knew it. What a strange feeling I had when I saw it. My aunt and uncle from NY , had a condo there. There were 2 couples, grandma had 2 sisters , one aunt  stayed home that night, the other husband went with her, so one person from each couple died.Not Gods plan. So sad, Date: 2025-07-08 01:29:47
# User: lisakramer.com, Content: Stories like this keep me up at night. I’m sad for the man and his loved ones.
#
# During my recent hospital stay a mixup led to me being repeatedly served a drug I don’t take. Each time I explained I don’t take the drug; 12 hours later it would show up again. Scary to think if I hadn’t been conscious., Date: 2025-07-08 01:29:48
# User: guydebord.bsky.social, Content: Este estilo que contiene su propia crítica debe expresar la dominación de la crítica presente sobre todo su pasado. A través de aquél, el modo de exposición de la teoría dialéctica manifiesta el espíritu negativo que está en ella. “La verdad no es como el producto en el cual no se encuentra más la, Date: 2025-07-08 01:30:01
# User: guydebord.bsky.social, Content: del sujeto por el predicado, logró el empleo el más consecuente de este estilo insurreccional que, de la filosofía de la miseria, obtiene la miseria de la filosofía. El détournement devuelve a la subversión las conclusiones críticas pasadas que han sido fijadas en verdades respetables, es decir, Date: 2025-07-08 01:30:02
# User: guydebord.bsky.social, Content: equivalente que dé cuenta de la significación que en su acepción criminal éste posee en francés. (N. del T.). que determina este empleo del détournement, confesado así por Kierkegaard, en el mismo libro: “Una sola acotación todavía a propósito de tus numerosas alusiones reprochando todas el hecho, Date: 2025-07-08 01:30:03
# User: periodistasunidos.bsky.social, Content: ¡Solidaridad con Texas! 💔 Sheinbaum lamenta las trágicas muertes causadas por las inundaciones. Un mensaje de apoyo en estos difíciles momentos. #FuerzaTexas #Sheinbaum #Inundaciones #Tragedia
#
# Más aquí: zurl.co/LfYTx, Date: 2025-07-08 01:30:00
# User: celosc.bsky.social, Content: fico passado com essa abestalhada, Date: 2025-07-08 01:30:06
# User: sratoz.com.br, Content: Aliás acabo de me dar conta: trekker não é assim. Ninguém fica arrasado quando um personagem de Star Trek morre, ou indignado, ou pessoalmente ofendido com nada. Mas vocês são. Ah, porque a Fleabag não sei quê, porque a personagem tal é pvta, porque a Cersei não podia, Date: 2025-07-08 01:30:08
# User: hellpasoian.bsky.social, Content: I’m sadly disappointed in @youranoncentral.bsky.social, Date: 2025-07-08 01:30:11
# User: gingerlucas.bsky.social, Content: this actually made me really sad www.instagram.com/reel/DLps-UU..., Date: 2025-07-08 01:30:18
# User: naosabelidar.bsky.social, Content: O pessoal coloca casado no tinder como se fosse uma QUALIDADE
# pqp
# Os mano nao faz nem questão de esconder, Date: 2025-07-08 01:30:21
# User: maebeasheep.bsky.social, Content: How about a hug too to help with that sadness
#
# Ft @blueskypuppy.bsky.social’s Mini with my Thylacine Cooper.
# #nsfwart #furrynsfw #nsfwfurry, Date: 2025-07-08 01:30:19
# User: ctvnews.bsky.social, Content: Kelly Clarkson fans aren’t the only ones saddened by her latest news., Date: 2025-07-08 01:30:26
# User: criminaalmambo.bsky.social, Content: La semana pasada Hugo Alconada menciono que Jaime Stiuso estaba enojado y comenzó una guerra interna. En Diciembre pasado, quien escribe mencionado sobre una persona que usaba los datos de su "amiga" la cual esta a su vez se tomo una foto frente a la "casa". Esto fue uno de los tantos motivos., Date: 2025-07-08 01:30:30
# User: jlroberson.bsky.social, Content: Sorry your sad, selfish incel loner Superman bombed so badly even with more chances than any director has ever been given.
# Seriously, I look at what Snyder got and think, imagine if they'd treated a GOOD director(Welled, Von Stroheim) well instead, Date: 2025-07-08 01:30:32
# User: sheepskin.bsky.social, Content: bought my partner a tamagotchi at ax and his first five minutes of playing it he goes “what does this sad ass baby want”, Date: 2025-07-08 01:30:55
# User: kickeybean.bsky.social, Content: I just have a feeling no one on inatagram is going to appreciate this.
#
# If you're sad and you know it, do a dance
#
# #animation, Date: 2025-07-08 01:30:58
# User: pmgibbs.bsky.social, Content: How sad and how beautiful that you were affected by his grief. I find comfort listening to this video, because it was a favorite spot for us. Again I thank you for your care, it means so much to me., Date: 2025-07-08 01:31:01
# User: romanparody.bsky.social, Content: I nod. "So do I... When Dahlia snaps she gets...scary not sad...just scary."
#
# #Aisling
#
# After I back the rest of my things, I take a deep breath., Date: 2025-07-08 01:31:03
# User: pikacha.bsky.social, Content: This is so sad and embaressing to watch
#
# But not as sad or embarrassing as knowing that on some percentage ofAmericans, this ridiculous mudslinging propaganda will actually work, Date: 2025-07-08 01:31:07
# ...
# User: jmuirclarke.bsky.social, Content: Hoy los extranjeros dicen dos cosas sobre CR: que es muy bonito y que es muy caro. Ahora resulta que Pilar Cisneros quiere bajar el salario mínimo. Esa señora odia a Costa Rica y a su gente, no encuentro otra explicación., Date: 2025-07-08 01:31:43
# User: gabirmmoura.bsky.social, Content: eita, sobre escolher shampu???, Date: 2025-07-08 01:31:28
# User: market-ocean-es.bsky.social, Content: Monitorea el comportamiento institucional: los inversores de cartera extranjeros recientemente reanudaron la compra de acciones indias tras cinco días de ventas. Este cambio a menudo señala un sentimiento cambiante sobre las condiciones del mercado., Date: 2025-07-08 01:31:53
# User: fr-france.bsky.social, Content: Île-de-France : les capitaines de bateaux aussi doivent rester sobres
#
# https://www.europesays.com/fr/233959/
#
# Les contrôles s’accentuent sur les cours d’eau de la région. La préfecture de région annonce que les brigades…#fr #france, Date: 2025-07-08 01:32:17
# User: hollyalisabeth.bsky.social, Content: Lol 1st it says evidence suggests, not facts and no link to the study and men's 2nd most cause for stroke? Alcohol so time to sober up guys, ENOUGH ALREADY!!, Date: 2025-07-08 01:32:25
# User: nervosocobaia.bsky.social, Content: se o Brasil e o brics tacarem foda-se no dolar, ele sobe ou desce?, Date: 2025-07-08 01:32:28
# User: carnivorcupcake.bsky.social, Content: I did mine hungover as well. Retook it sober and did worse. I think there’s something to not giving a shit and freeing your mind a little bit., Date: 2025-07-08 01:32:28
# User: tuitaavivi.bsky.social, Content: Antes as músicas dele pareciam normais, agora todas parecem que é sobre eles, Date: 2025-07-08 01:32:44
# User: brasil247.bsky.social, Content: “Lamentável e dilacerante", diz ministra sobre morte jovem por polícia, Date: 2025-07-08 01:33:22
# User: linzobean.bsky.social, Content: SOBBU SOBBU SNIIIFLES MINH........!!!!!!!!!!, Date: 2025-07-08 01:33:38
# User: bitmicha.bsky.social, Content: ufa o gostoso ta vivo tudo sob controle, Date: 2025-07-08 01:33:40
# User: perrito-perdido.bsky.social, Content: Me da seguido, sobre todo por comer rápido, pero solo espero porque también se me pasa fácil., Date: 2025-07-08 01:33:51
# User: faelsemra.bsky.social, Content: Você querer surtar comigo sobre que seu namorado fez algo, blz, eu surto junto contigo, MAS AGORA O ÚNICO ASSUNTO Q CE TEM É ISSO? ESPERO Q SE SEPAREM LOGO, Date: 2025-07-08 01:33:49
# User: glitical.bsky.social, Content: A Argentina suspendeu os julgamentos para extraditar foragidos, procurados pelos crimes do 8 de janeiro de 2023. Nada novo sobre o modus operandi de Javier! #FueraMilei., Date: 2025-07-08 01:33:51
# User: casambadelixo.bsky.social, Content: Acho q criança tem q ter consentimento sobre uso de imagem mas agora a questão médica me pegou legal, pq ao mesmo tempo q faz sentido eu me pergunto se tem como explicar de uma forma boa pra uma criança a importância de ela por ex tomar vacina por mais que doa, ou arrancar um dente etc, Date: 2025-07-08 01:34:05
# User: trocaequivalente.bsky.social, Content: Gachiakuta 01: É um primeiro episódio bem amarrado e impactante que já vende a obra muito bem. É sobre um jovem acusado injustamente de um crime e que é exilado num lixão e que vai tentar se vingar da "sociedade" corrompida que fiz isso com ele., Date: 2025-07-08 01:34:26
# User: pedrogiordan.bsky.social, Content: UEFA CHAMPIONS LEAGUE 2025/2026
#
# Amanhã, começa a nova temporada da Liga dos Campeões da Europa. No meu blog, vocês podem conferir mais detalhes sobre os confrontos da 1ª fase qualificatória do torneio.
#
# Espero que gostem.
#
# blogdegoleada.blogspot.com/2025/07/a-ue..., Date: 2025-07-08 01:34:43
# User: brodrii.bsky.social, Content: Eu não ficava tão animado em tuitar sobre novela desde Bianca Bin botando Marieta Severo pra mamar com "vocês não imaginam o prazer que é estar de volta"., Date: 2025-07-08 01:34:55
# User: ranier.bsky.social, Content: Vamos aumentar o IOF para 25% sobre os milionários se quiser ótimo se não quiser linha na pipa 🪁, detalhe 25% ainda é pouco…., Date: 2025-07-08 01:34:59
# User: beemato.bsky.social, Content: KAWAII LAB. SESSIONのチケットプレゼントと楽しい特典を見逃すな！ #KAWAII_LAB #Pontaパス #ASOBISYSTEM
#
# Pontaパス会員限定で、KAWAII LAB. SESSIONのチケット抽選が実施。エンタメ特典も満載の内容をお届けします。, Date: 2025-07-08 10:35:10
# User: samirsalimjr.com, Content: Ligando pro @chicobarney.bsky.social pra saber de antemão a opinião sobre A CENA, Date: 2025-07-08 01:35:24
# User: fariawilliam.bsky.social, Content: O Leandro Vieira canetou demais quando opinou sobre o samba do Caju. Ruim toda vida., Date: 2025-07-08 01:35:29
# User: geoxzs.bsky.social, Content: eu sou ignorante ao ponto de te tirar da minha se vc disser algo sobre as mscs q fui criada, e vai por mim? eu ja fiz isso., Date: 2025-07-08 01:35:34
# User: jnascim.info, Content: O que esse episódio nos ensina, amigos? Tem que planejar o discurso. Se a Raquel tivesse começado de trás pra frente — falando sobre César e os dólares do Marco Aurélio — Odete teria (talvez) tido outra postura #ValeTudo, Date: 2025-07-08 01:35:44
# User: chavaluria.bsky.social, Content: Ya nos sabemos también la cantaleta de Homme sobre una potencial reunión de Kyuss
#
# Porque siempre dice que "chance y sí" y al final, Bjork o García lo contactan pal'seguimiento y los deja colgados
#
# Hasta no verlos juntos tocando un 1er gig, no creer, Date: 2025-07-08 01:35:54
# User: amandawastefree.bsky.social, Content: A few days ago a driver didn't see me & failed to stop at a roadabout, hitting me and knocking me off my bike. Luckily I got out fairly unscatched - a sore bum & shoulder, bent derailleur on my bike. Reading @juliefairey.bsky.social article was sobering. thespinoff.co.nz/society/08-0..., Date: 2025-07-08 01:35:49
# User: swaywithme.bsky.social, Content: -- a una niña, hombre tenía que ser. —PERO MIKU POR DIOS— Pero sobre eso que dices, sí, aquí hasta hay uniformes médicos y otras cosas... Lo normal que podría tener un hospital hasta cierto punto. Lo que me sorprende es que no hay una sala de operaciones... --, Date: 2025-07-08 01:35:52
# User: swaywithme.bsky.social, Content: -- No se van a desaparecer por una noche, Natalie.
#
# Esperen.
# En qué momento se le sentó en los hombr--. Bueno, qué más da, va a sujetarle de las piernitas, así la mantiene bien sujeta.
#
# Va a salir con cuidado del almacén, sobretodo para que el marco de la puerta no le pegue a la chiquita. --, Date: 2025-07-08 01:35:52
# User: ineselpez.bsky.social, Content: Los tipos que pegan afiches de conciertos en el cruce de Baquedano no tienen códigos. Constante actualización de cartelera afiche-sobre-afiche., Date: 2025-07-08 01:36:01
# User: anthrodiva.bsky.social, Content: Lolsob, Date: 2025-07-08 01:36:13
# User: unoticias.bsky.social, Content: Los líderes se ponen de acuerdo sobre cuáles serán los “dirigentes más competitivos” para ganar los comicios, Date: 2025-07-08 01:36:24
# User: carpenter22.bsky.social, Content: Cruz voted to KILL NOAA and now he's trying to play hero after 100+ are dead BECAUSE OF HIS ACTIONS? You're worthless, ted and you're an immigrant from Canada, how about that? Plus, you're Hispanic--everything MAGA is AGAINST. Vote this SOB, kid killer out. #Cruz #Texas #voting #Senate #NOAA #storm, Date: 2025-07-08 01:36:33
# User: acredite.bsky.social, Content: Olha....eu sou forte e me emocionei algumas vezes...Amor basta, e sobra., Date: 2025-07-08 01:36:34
# User: madamabovary.bsky.social, Content: Hahaha sí! mas foi um momento que pensei: o que minha psicóloga diria sobre isso?, Date: 2025-07-08 01:37:02
# User: choqueweb.bsky.social, Content: O astronauta Scott Kelly uma vez levou escondido um traje completo de gorila a bordo da Estação Espacial Internacional. Ele não contou a ninguém sobre isso. Um dia, sem ninguém saber, ele colocou e deu nisso..., Date: 2025-07-08 01:37:22
# User: alexmonteiro93.bsky.social, Content: Ministério dos Direitos Humanos deve acompanhar investigações sobre morte de adolescente em Manaus - www.acritica.com/geral/minist..., Date: 2025-07-08 01:37:29
# User: updatenewsbr.bsky.social, Content: O astronauta Scott Kelly uma vez levou escondido um traje completo de gorila a bordo da Estação Espacial Internacional. Ele não contou a ninguém sobre isso. Um dia, sem ninguém saber, ele colocou e deu nisso..., Date: 2025-07-08 01:37:53
# User: nncyboy.bsky.social, Content: super entendo, mas sei que tem coisa que realmente um vídeo ajuda (ou é essencial), POREM como um divo comentou aqui, as vezes eu só quero saber quanto tempo tenho que ferver tal coisa, não preciso ver um vídeo de dez minutos sobre isso!!!!!
#
# (ainda odeio ter que ver vídeo msm pro q precisa), Date: 2025-07-08 01:38:09
# User: travelspot.bsky.social, Content: asobito（アソビト）から「焚き火ストレージ＆キャリー」が7月18日（金）に発売！asobitoユーザーのアイデアを商品化。, Date: 2025-07-08 01:38:11
# User: jaredmerlinxxx.bsky.social, Content: Listen to this HATEFUL MAGA CHRISTIAN NATIONALIST SOB Pastor
#
# youtu.be/GaOIPPzQQbE?..., Date: 2025-07-08 01:38:12
# User: thaytha.bsky.social, Content: Acho que tem um discurso sobre moralidade ali, mais do que sobre homem. A questão de ter acusado alguém inocente pesa para a Raquel, personagem moralmente incorrompivel, e por fim machuca pq ela ama ele., Date: 2025-07-08 01:38:33
# User: borgeszb2403.bsky.social, Content: incrível como TUDO sobre pra mim tmnc, Date: 2025-07-08 01:38:39
# User: jaredmerlin.bsky.social, Content: Listen to this HATEFUL SOB MAGA CHRISTIAN NATIONALIST Pastor
#
# youtu.be/GaOIPPzQQbE?..., Date: 2025-07-08 01:38:44
# User: vinchenzojackal.bsky.social, Content: Happy BDay and happy sobriety anniversary.
# Proud of you and hope you had plenty of delicious treats to celebrate your birthday., Date: 2025-07-08 01:38:59
# User: alinnecmarques.bsky.social, Content: #SingSing é bonito que só. Resiliência pura. É sobre um grupo de pessoas encarceradas que encontram o teatro como refúgio, cura e redenção. Tem partes pesadas, como a vida. Acaba com quentinho de que a arte salva., Date: 2025-07-08 01:39:05
# User: maryviolin.art, Content: Tem alguns aspectos que uns ganham dos outros, mas em geral todos cumprem bem a função...
#
# Fico pensando em abrir um canal no YouTube pra falar mais sobre, Date: 2025-07-08 01:39:16
# User: paoolinha.bsky.social, Content: "empreendedor é quem tem dinheiro, você é sobrevivente Luis", essa fala é uma pérola maravilhosa demais, verdadeira demais, brasileira pra cacete, obrigada #PabloeLuisao, @paulovieira.bsky.social + @caitomainier.bsky.social e todos envolvidos, Date: 2025-07-08 01:39:18
# User: spagetka.bsky.social, Content: Jsem vůbec netušila, že v sobě ještě mám tohle odhodlání, ve 4 sedět u počítače a psát.
# Blbé je, že od 2 pozoruju, jak můj mozek spinká, takže to budu hezky zase přepisovat 🤦‍♀️, Date: 2025-07-08 01:39:39
# User: rbdeternally.bsky.social, Content: Diretamente do “Aeroporto: Área Restrita”, Maite Perroni responde algumas perguntas sobre Pedro Damian, suposto roubo no RBD e sobre Anahi e Dulce Maria:
#
# “Eu não escutei, eu não sei”, diz Maite, após Pedro Damián propor um reencontro do RBD em uma entrevista. @maiperroni.bsky.social, Date: 2025-07-08 01:39:44
# User: rbdeternally.bsky.social, Content: Sobre o caso do suposto roubo do ex - maneger Guillermo Rosas, contra o RBD, Maite fala: “É um tema muito complexo e cada um viu a história de uma forma diferente. É o que posso dizer!”, Date: 2025-07-08 01:39:44
# User: rbdeternally.bsky.social, Content: E em seguida, ao ser questionada sobre a sua amizade com Anahi e Dulce Maria, Maite Perroni manda beijos e dá as costas, seguindo a mesma postura de Christian Chávez, ao ser questionado sobre Anahi, no final de maio desse ano., Date: 2025-07-08 01:39:44
# User: mcsweeneys.net, Content: California sober: No alcohol or drugs except marijuana
#
# New York sober: No alcohol or drugs except cocaine
#
# Maine sober:  No addictive drugs except lobster rolls, Date: 2025-07-08 01:40:14
# User: g1-news.bsky.social, Content: Amazonas participa de maior pesquisa sobre favelas do Brasil para traçar perfil das periferias, Date: 2025-07-07 22:40:17
# User: karinecoelho.bsky.social, Content: O que eu dizia esses dias sobre resenha de livro/filme em vídeo, meu irmão em Cristo eu quero LER, PFV ESCREVA PARA EU LEEEEEEER, Date: 2025-07-08 01:40:41
# User: bttlborn.bsky.social, Content: voce ia estar falando na terapia sobre a vez que sua mae quebrou uma cadeira de plastico nas suas costas por anos. isso aconteceu comigo aos 6 anos de idade. e eu ainda to aqui. e eu ainda consigo ser bom, seu bosta, Date: 2025-07-08 01:40:41
# User: thaytha.bsky.social, Content: Acho que essa versão de Vale Tudo tem um discussão forte sobre moralidade. Raquel não fica rica exatamente por puro trabalho e esforço, pq vai ter o dinheiro da Celina, teve o empréstimo do Poliana para o restaurante, mas ELA mesmo não precisou se corromper em nenhum nível. Todos os outros sim., Date: 2025-07-08 01:40:57
# User: acredite.bsky.social, Content: Amor basta, e sobra. Eles recomeçam,  se precisar., Date: 2025-07-08 01:41:28
# User: vitorio.neocities.org, Content: Estou vendo um vídeo de 19 minutos com gameplay de Horizon Chase no fundo e narração loquendo sobre a Natalhando, Date: 2025-07-08 01:42:00
# User: ronaldo-st.bsky.social, Content: BRASIL SOBERANO
# O BRASIL É DOS BRASILEIROS
# NÃO VAMOS RECUAR
# NÃO SOMOS COLÔNIA, Date: 2025-07-08 01:41:54
# User: new3rd.bsky.social, Content: asobitoがユーザーの声を活かした新商品「焚き火ストレージ＆キャリー」を発売 #大阪府 #大阪市 #asobito #アウトドアグッズ #焚き火ストレージ
#
# アウトドアブランドasobitoが、ユーザーのアイデアを反映した新商品「焚き火ストレージ＆キャリー」を発表しました。7月18日発売。特徴や開発秘話をご紹介。, Date: 2025-07-08 10:42:48
# User: carlosferia.bsky.social, Content: Israel planea encerrar a toda la población de #Gaza en una "ciudad" levantada sobre las ruinas de Rafah, en el sur de la Franja
#
# “Ciudad Humanitaria”
#
#  www.eldiario.es/1_bde90d?utm..., Date: 2025-07-08 01:43:20
# User: billbindc.bsky.social, Content: "Washington, D.C. sober: Addicted to any sport unless I have to change a team name to be less racist", Date: 2025-07-08 01:43:33
# User: boytoys96.bsky.social, Content: I’m glad to finally have a consistent support network. I’m 9 days sober and get cravings every now and then.
#
# Then I get reminded of why I stay sober ❤️, Date: 2025-07-08 01:43:40
# User: aloyokon.bsky.social, Content: Or this SOB, Date: 2025-07-08 01:43:44
# User: virginianja.bsky.social, Content: A Cacá VOANDO depois de levar um choque na cerca elétrica! 🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣😅😅😅😅😅😅🤣🤣🤣🤣🤣🤣
#
# O mais louco é que ela sobreviveu! A póbi da doguinha passou por tanta coisa!!!, Date: 2025-07-08 01:43:47
# User: lucasoct.bsky.social, Content: Quem quiser conhecer o MyFlightradar24, pode olhar essa matéria que escrevi no @avioesemusicas.com sobre o site.
#
# avioesemusicas.com/myflightrada..., Date: 2025-07-08 01:44:50
# User: greatestpuzzler.bsky.social, Content: PrinceVince28
#
# I fucking hate My Older Brother so badly.
#
# I just want that wasted alcoholic piece of shit dead.
#
# I do not have to pay for his hospital bills just because he wants to be a goddamn sobered retard., Date: 2025-07-08 01:43:51
# User: elpais.com, Content: 🇨🇴 El expresidente Álvaro Uribe Vélez ha llegado al momento clave de un caso penal en su contra. La jueza Sandra Heredia debe definir si él se convertirá en el primer jefe de Estado colombiano en ser condenado por un proceso de soborno y fraude social.elpais.com/00wbi14, Date: 2025-07-08 01:43:52
# User: 2rZiKKbOU3nTafniR2qMMSE0gwZ.activitypub.awakari.com.ap.brid.gy, Content: Open Redirect vulnerability in SAP BusinessObjects Content Administrator work... Due to insufficient sanitization in the SAP BusinessObjects Content Administrator Workbench, attackers could craft m...
#
#
# Origin | Interest | Match, Date: 2025-07-08 00:38:25
# User: toxic-metal-zine.bsky.social, Content: Deadly Mourning Shadows presents Lamentations of a Dying Heart to be released on July 6, 2025! Get the album details now @ toxicmetalzine.com/post/deadly-..., Date: 2025-07-08 01:40:10

# %%
# Word Cloud Generation in Notebook
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re
from collections import Counter

# Comprehensive stop words
STOP_WORDS = {
    'a', 'an', 'and', 'are', 'as', 'at', 'be', 'by', 'for', 'from', 'has', 'he', 
    'in', 'is', 'it', 'its', 'of', 'on', 'that', 'the', 'to', 'was', 'were', 
    'will', 'with', 'the', 'this', 'but', 'they', 'have', 'had', 'what', 'said', 
    'each', 'which', 'she', 'do', 'how', 'their', 'if', 'up', 'out', 'many', 
    'then', 'them', 'these', 'so', 'some', 'her', 'would', 'make', 'like', 'into', 
    'him', 'time', 'two', 'more', 'very', 'when', 'come', 'may', 'say', 'get', 
    'use', 'your', 'way', 'about', 'than', 'first', 'been', 'call', 'who', 'oil', 
    'sit', 'now', 'find', 'long', 'down', 'day', 'did', 'get', 'come', 'made', 
    'may', 'part', 'over', 'new', 'sound', 'take', 'only', 'little', 'work', 
    'know', 'place', 'year', 'live', 'me', 'back', 'give', 'most', 'very', 'after',
    'don', 'can', 'said', 'go', 'see', 'no', 'could', 'people', 'my', 'one',
    'rt', 'via', 'http', 'https', 'www', 'com', 'bsky', 'social', 'at',
    'really', 'actually', 'literally', 'basically', 'totally', 'definitely', 
    'probably', 'maybe', 'perhaps', 'seems', 'looks', 'feels', 'sounds',
    'something', 'someone', 'somewhere', 'somehow', 'sometimes', 'anything', 
    'anyone', 'anywhere', 'anytime', 'everything', 'everyone', 'everywhere',
    'nothing', 'nobody', 'nowhere', 'never', 'always', 'often', 'usually',
    'yes', 'no', 'ok', 'okay', 'well', 'oh', 'ah', 'um', 'uh', 'er', 'hmm'
}

def clean_text_for_wordcloud(text):
    """Clean text for word cloud generation"""
    text = text.lower()
    # Remove URLs
    text = re.sub(r'http[s]?://\S+', '', text)
    # Remove mentions and hashtags
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#\w+', '', text)
    # Remove special characters
    text = re.sub(r'[^\w\s]', ' ', text)
    # Remove extra whitespace
    text = ' '.join(text.split())
    return text

def create_notebook_wordcloud(search_term=None, hours_ago=24, colormap='viridis'):
    """Create a word cloud in the notebook"""
    
    # Get posts
    if search_term:
        query = """
        SELECT text FROM posts 
        WHERE created_at > DATE_SUB(NOW(), INTERVAL %s HOUR)
        AND text LIKE %s
        AND LENGTH(text) > 10
        """
        posts = data.fetch_all(query, (hours_ago, f'%{search_term}%'))
    else:
        query = """
        SELECT text FROM posts 
        WHERE created_at > DATE_SUB(NOW(), INTERVAL %s HOUR)
        AND LENGTH(text) > 10
        """
        posts = data.fetch_all(query, (hours_ago,))
    
    if not posts:
        print("No posts found!")
        return
    
    print(f"Found {len(posts)} posts")
    
    # Clean and combine text
    all_text = []
    for post in posts:
        cleaned = clean_text_for_wordcloud(post['text'])
        if len(cleaned.strip()) > 5:
            all_text.append(cleaned)
    
    combined_text = ' '.join(all_text)
    
    # Create word cloud
    wordcloud = WordCloud(
        width=1200, 
        height=600,
        max_words=150,
        background_color='white',
        colormap=colormap,
        stopwords=STOP_WORDS,
        relative_scaling=0.5,
        collocations=False
    ).generate(combined_text)
    
    # Display
    plt.figure(figsize=(15, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    
    title = f"Word Cloud"
    if search_term:
        title += f" - '{search_term}' posts"
    title += f" (last {hours_ago} hours)"
    
    plt.title(title, fontsize=16, fontweight='bold', pad=20)
    plt.tight_layout()
    plt.show()
    
    # Show top words
    words = combined_text.split()
    word_freq = Counter(word for word in words if word not in STOP_WORDS and len(word) > 2)
    
    print(f"\nTop 15 most frequent words:")
    for i, (word, count) in enumerate(word_freq.most_common(15), 1):
        print(f"   {i:2d}. {word:<15} ({count} times)")

# Example usage:
print("Word cloud functions loaded! Use:")
print("create_notebook_wordcloud()  # All posts")
print("create_notebook_wordcloud('love', colormap='plasma')  # Love posts with plasma colors")
# Out:
# Word cloud functions loaded! Use:
# create_notebook_wordcloud()  # All posts
# create_notebook_wordcloud('love', colormap='plasma')  # Love posts with plasma colors

# %%
#clear jupyter output
import time
from IPython.display import clear_output
clear_output()
#posts per user top posters, get their top keyworkds per user

top_users_query = """
SELECT author_handle, COUNT(*) as post_count
FROM posts
WHERE created_at > NOW() - INTERVAL 1 HOUR
GROUP BY author_handle
ORDER BY post_count DESC
LIMIT 5
"""
while True:
    top_users = data.fetch_all(top_users_query)
    clear_output()
    print("\nTop 5 users by post count:")
    for user in top_users:
        print(f"User: {user['author_handle']}, Posts: {user['post_count']}")    
        #get top keywords for this user
        user_posts = data.get_posts_by_user(user['author_handle'])
        user_text = ' '.join(post['text'] for post in user_posts)
        user_words = re.findall(r'\b\w+\b', user_text.lower())
        user_word_freq = Counter(word for word in user_words if word not in STOP_WORDS and len(word) > 2)
        print(f"  Top keywords: {', '.join(word for word, count in user_word_freq.most_common(20))}")   
        print() 
    time.sleep(1)  # Pause to avoid overwhelming the output
# Out:
# Top 5 users by post count:
# User: longtail.news, Posts: 461
#   Top keywords: feed, july, 2025, monday, news, published, latest, tuesday, ukraine, world, ukrainian, national, unn, wire, jalopnik, west, times, today, oregonlive, india
#
# User: floofypuppy.bsky.social, Posts: 260
#   Top keywords: woof, roof, ruff, arf, grr, bork, yip
#
# User: new3rd.bsky.social, Posts: 247
#   Top keywords: 東京都, 大阪府, 大阪市, 中央区, 千代田区, 愛知県, 新宿区, 渋谷区, 神奈川県, が登場, 品川区, 2025, 福岡県, 京都府, fit, 名古屋市, 福岡市, summer, を発表, が開催
#
# User: gjkhgvvvyy.bsky.social, Posts: 207
#   Top keywords: beg, you, help, ahmed, kiss, head, days, left, save, son, life, tired, donating, sharing, campaign, pinned, page, mjtothemax, jim7654, swordandquill
#
# User: movies-on-sale.bsky.social, Posts: 105
#   Top keywords: available, genre, cast, trailer, reviews, movie, today, rottentomatoes, itunes, audio, ray, off, amazon, blu, imdb, comedy, germany, john, dolby, action
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 16
#       7 top_users_query = """
#       8 SELECT author_handle, COUNT(*) as post_count
#       9 FROM posts
#    (...)     13 LIMIT 5
#      14 """
#      15 while True:
# ---> 16     top_users = data.fetch_all(top_users_query)
#      17     clear_output()
#      18     print("\nTop 5 users by post count:")
#
# Cell In[1], line 22, in MySQLDB.fetch_all(self, query, params)
#      20 conn = self.get_connection()
#      21 cur = conn.cursor(dictionary=True)
# ---> 22 cur.execute(query, params)
#      23 result = cur.fetchall()
#      24 conn.close()
#
# File ~/.local/lib/python3.11/site-packages/mysql/connector/cursor_cext.py:356, in CMySQLCursor.execute(self, operation, params, map_results)
#     348 self._executed = (
#     349     self._stmt_partition["single_stmts"].popleft()
#     350     if map_results
#     351     else self._stmt_partition["mappable_stmt"]
#     352 )
#     354 try:
#     355     self._handle_result(
# --> 356         self._connection.cmd_query(
#     357             self._stmt_partition["mappable_stmt"],
#     358             raw=self._raw,
#     359             buffered=self._buffered,
#     360             raw_as_string=self._raw_as_string,
#     361         )
#     362     )
#     363 except MySQLInterfaceError as err:
#     364     if hasattr(err, "errno"):
#
# File ~/.local/lib/python3.11/site-packages/mysql/connector/opentelemetry/context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File ~/.local/lib/python3.11/site-packages/mysql/connector/connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     769     self._query = query
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
#
# KeyboardInterrupt:

# %%
#right wing call words
right_wing_words = [
    # Core conservative values
    "patriot", "freedom", "liberty", "constitution", "constitutional", "founding fathers",
    "conservative", "republican", "GOP", "right wing", "traditional values", "family values",
    "christian values", "moral values", "religious freedom", "faith", "god", "prayer",
    
    # Trump & MAGA movement
    "maga", "trump", "trump 2024", "america first", "make america great",
    "drain the swamp", "deep state", "establishment", "swamp", "fake news",
    "mainstream media", "MSM", "liberal media", "biased media",
    
    # Nationalism & patriotism
    "nationalism", "patriotism", "american exceptionalism", "flag", "anthem",
    "pledge of allegiance", "national pride", "america", "USA", "united states",
    
    # Government & politics
    "small government", "limited government", "states rights", "federalism",
    "constitutional rights", "bill of rights", "separation of powers",
    "law and order", "rule of law", "individual rights", "personal responsibility",
    
    # Economic conservatism
    "free market", "capitalism", "free enterprise", "entrepreneur", "business owner",
    "job creator", "economic freedom", "lower taxes", "tax cuts", "deregulation",
    "fiscal responsibility", "balanced budget", "national debt", "spending cuts",
    
    # Gun rights
    "2nd amendment", "second amendment", "gun rights", "pro-gun", "NRA",
    "right to bear arms", "self defense", "concealed carry", "open carry",
    "gun owner", "firearm", "shall not be infringed",
    
    # Military & law enforcement
    "military", "armed forces", "veteran", "support our troops", "police",
    "law enforcement", "blue lives matter", "back the blue", "thin blue line",
    "national defense", "strong defense", "peace through strength",
    
    # Immigration & border
    "border security", "illegal immigration", "border wall", "immigration control",
    "secure the border", "deportation", "illegal alien", "sanctuary cities",
    "chain migration", "merit based immigration",
    
    # Social issues
    "pro-life", "right to life", "unborn", "sanctity of life", "abortion",
    "traditional marriage", "nuclear family", "parental rights", "school choice",
    "homeschool", "religious liberty", "conscience rights",
    
    # Anti-left sentiments
    "anti-socialism", "anti-communist", "anti-marxist", "anti-woke", "woke",
    "cancel culture", "political correctness", "virtue signaling", "identity politics",
    "cultural marxism", "critical race theory", "CRT", "leftist", "liberal",
    "progressive agenda", "radical left", "socialist agenda",
    
    # Sovereignty & anti-globalism
    "national sovereignty", "anti-globalism", "america first", "globalist",
    "new world order", "UN", "international law", "foreign aid",
    "trade deficit", "fair trade", "energy independence",
    
    # Populist themes
    "drain the swamp", "corrupt politicians", "career politicians", "term limits",
    "government accountability", "transparency", "taxpayer", "hard working americans",
    "forgotten americans", "silent majority", "common sense", "real americans",
    
    # Conspiracy & fringe terms
    "deep state", "shadow government", "mainstream narrative", "alternative facts",
    "sovereign citizen", "constitutionalist", "militia", "three percenter",
    "don't tread on me", "come and take it", "molon labe",
    
    # Modern conservative media
    "tucker carlson", "fox news", "newsmax", "OAN", "breitbart", "daily wire",
    "podcast", "alternative media", "citizen journalist", "truth",
    
    # Election & voting
    "election integrity", "voter ID", "stop the steal", "rigged election",
    "election fraud", "ballot harvesting", "voter fraud", "audit",
    
    # Cultural issues
    "western civilization", "judeo-christian", "heritage", "tradition",
    "cultural decline", "moral decay", "family breakdown", "gender ideology",
    "transgender", "pronouns", "biological sex", "women's sports"
]
def find_right_wing_posts():
    right_wing_posts = []
    for word in right_wing_words:
        posts = data.search_posts_by_text(word)
        right_wing_posts.extend(posts)
    return right_wing_posts
right_wing_posts = find_right_wing_posts()
stats = {
    'most common words': Counter(),
    'total posts': 0,
    'unique authors': set(),
    'total users': 0,
}
for post in right_wing_posts:
    stats['total posts'] += 1
    stats['unique authors'].add(post['author_did'])
    words = re.findall(r'\b\w+\b', post['text'].lower())
    stats['most common words'].update(word for word in words if word not in STOP_WORDS and len(word) > 2)
stats['total users'] = len(stats['unique authors'])
print(f"Found {stats['total posts']} right-wing posts from {stats['total users']} unique users")
print("Most common words:")
for word, count in stats['most common words'].most_common(20):
    print(f"  {word}: {count} times")
# Out:
# Found 24272 right-wing posts from 13864 unique users
# Most common words:
#   you: 5095 times
#   trump: 4374 times
#   not: 2986 times
#   just: 2354 times
#   all: 2304 times
#   his: 1668 times
#   there: 1414 times
#   because: 1108 times
#   our: 1062 times
#   que: 1037 times
#   think: 965 times
#   even: 907 times
#   news: 873 times
#   god: 820 times
#   2025: 807 times
#   america: 806 times
#   why: 760 times
#   maga: 744 times
#   around: 743 times
#   good: 738 times

# %%
left_wing_words = [
    # Core progressive values
    "equality", "justice", "progressive", "social justice", "equity", "fairness",
    "liberation", "solidarity", "community", "collective action", "grassroots",
    
    # Economic justice
    "living wage", "minimum wage", "workers rights", "union", "unionize", "strike",
    "collective bargaining", "wealth inequality", "income inequality", "tax the rich",
    "universal basic income", "UBI", "affordable housing", "rent control",
    "student debt", "free college", "free tuition", "public education funding",
    
    # Environmental & climate
    "climate change", "climate crisis", "climate action", "environment", "green",
    "renewable energy", "solar", "wind power", "sustainability", "carbon tax",
    "fossil fuels", "green new deal", "environmental justice", "clean energy",
    
    # Healthcare & social services
    "universal healthcare", "medicare for all", "single payer", "public option",
    "mental health", "reproductive rights", "bodily autonomy", "abortion access",
    
    # Social justice & civil rights
    "diversity", "inclusion", "LGBTQ+", "LGBTQIA", "transgender rights", "gay rights",
    "feminism", "feminist", "women's rights", "gender equality", "pay gap",
    "anti-racism", "racial justice", "black lives matter", "BLM", "systemic racism",
    "police reform", "criminal justice reform", "prison abolition", "restorative justice",
    "voter rights", "voting rights", "gerrymandering", "democracy reform",
    
    # Immigration & refugee rights
    "immigration reform", "refugee rights", "DACA", "dreamers", "sanctuary cities",
    "border policy", "family separation", "detention centers",
    
    # Anti-establishment & system change
    "anti-capitalism", "anti-imperialism", "anti-fascism", "antifa", "resist",
    "revolution", "systemic change", "democratic socialism", "socialism",
    "capitalism critique", "corporate power", "big pharma", "wall street",
    
    # International & peace
    "anti-war", "peace", "diplomacy", "human rights", "international law",
    "global south", "decolonization", "indigenous rights", "land back",
    
    # Modern progressive terms
    "intersectionality", "privilege", "allyship", "mutual aid", "harm reduction",
    "reparations", "defund police", "abolition", "prison industrial complex",
    "food justice", "housing justice", "climate justice", "economic justice",
    "disability rights", "accessibility", "neurodiversity"
]
def find_left_wing_posts():
    left_wing_posts = []
    for word in left_wing_words:
        posts = data.search_posts_by_text(word)
        left_wing_posts.extend(posts)
    return left_wing_posts
left_wing_posts = find_left_wing_posts()
stats = {
    'most common words': Counter(),
    'total posts': 0,
    'unique authors': set(),
    'total users': 0,
}
for post in left_wing_posts:
    stats['total posts'] += 1
    stats['unique authors'].add(post['author_did'])
    words = re.findall(r'\b\w+\b', post['text'].lower())
    stats['most common words'].update(word for word in words if word not in STOP_WORDS and len(word) > 2)
stats['total users'] = len(stats['unique authors'])
print(f"Found {stats['total posts']} left-wing posts from {stats['total users']} unique users")
print("Most common words:")
for word, count in stats['most common words'].most_common(20):
    print(f"  {word}: {count} times")
# Out:
# Found 2249 left-wing posts from 1796 unique users
# Most common words:
#   you: 484 times
#   peace: 357 times
#   not: 268 times
#   all: 254 times
#   community: 232 times
#   just: 211 times
#   trump: 206 times
#   prize: 202 times
#   our: 182 times
#   nobel: 160 times
#   green: 138 times
#   his: 125 times
#   there: 115 times
#   justice: 111 times
#   climate: 107 times
#   change: 102 times
#   here: 91 times
#   war: 91 times
#   because: 90 times
#   want: 90 times

# %%
from tqdm import tqdm

# Analyze each user's post history based on the keywords for right and left wing and determine how many total right and left wing users we have
def analyze_user_post_history(user_posts):
    user_stats = {
        'right wing': 0,
        'left wing': 0
    }
    for post in user_posts:
        if any(word in post['text'].lower() for word in right_wing_words):
            user_stats['right wing'] += 1
        if any(word in post['text'].lower() for word in left_wing_words):
            user_stats['left wing'] += 1
    return user_stats
# Analyze all users
user_analysis = {}
for user in tqdm(data.fetch_all("SELECT DISTINCT author_handle FROM posts")):
    user_posts = data.get_posts_by_author_handle(user['author_handle'])
    user_analysis[user['author_handle']] = analyze_user_post_history(user_posts)
# Count total right and left wing users
total_right_wing_users = sum(1 for stats in user_analysis.values() if stats['right wing'] > 0)
total_left_wing_users = sum(1 for stats in user_analysis.values() if stats['left wing'] > 0)
print(f"Total right-wing users: {total_right_wing_users}")
print(f"Total left-wing users: {total_left_wing_users}")
# Out:
#  35%|███▍      | 18533/53244 [00:51<02:13, 259.11it/s]
# Connection attempt 1 failed: 2003 (HY000): Can't connect to MySQL server on 'mariadb:3306' (99). Retrying in 1.0 seconds...
#  36%|███▌      | 19044/53244 [00:53<01:10, 483.56it/s]
# Connection attempt 1 failed: 2003 (HY000): Can't connect to MySQL server on 'mariadb:3306' (99). Retrying in 1.0 seconds...
# Connection attempt 2 failed: 2003 (HY000): Can't connect to MySQL server on 'mariadb:3306' (99). Retrying in 2.1 seconds...
# Connection attempt 3 failed: 2003 (HY000): Can't connect to MySQL server on 'mariadb:3306' (99). Retrying in 4.2 seconds...
# Connection attempt 4 failed: 2003 (HY000): Can't connect to MySQL server on 'mariadb:3306' (99). Retrying in 8.3 seconds...
